# %%
# Calculo correlación
import pandas as pd
data = {
    'ventas': [200, 220, 210, 205, 215, 225],
    'gdp_per_capita': [30000, 32000, 31000, 30500, 31500, 32500],
    'healthy_life_expectancy': [70, 72, 71, 70.5, 71.5, 73],
    'freedom_to_make_life_choices': [0.8, 0.85, 0.82, 0.81, 0.84, 0.86]
}

df = pd.DataFrame(data)
# Supongamos que df es nuestro DataFrame cargado y limpio
# Cálculo de la correlación de Pearson
correlation_matrix = df.corr(method='pearson')
print(correlation_matrix)

# Cálculo de la correlación de Spearman
spearman_corr = df.corr(method='spearman')
print(spearman_corr)

# Cálculo de la correlación de Kendall
kendall_corr = df.corr(method='kendall')
print(kendall_corr)
# Out:
#                                 ventas  gdp_per_capita  \
# ventas                        1.000000        1.000000
# gdp_per_capita                1.000000        1.000000
# healthy_life_expectancy       0.989743        0.989743
# freedom_to_make_life_choices  0.993859        0.993859
#
#                               healthy_life_expectancy  \
# ventas                                       0.989743
# gdp_per_capita                               0.989743
# healthy_life_expectancy                      1.000000
# freedom_to_make_life_choices                 0.978076
#
#                               freedom_to_make_life_choices
# ventas                                            0.993859
# gdp_per_capita                                    0.993859
# healthy_life_expectancy                           0.978076
# freedom_to_make_life_choices                      1.000000
#                               ventas  gdp_per_capita  healthy_life_expectancy  \
# ...

# %%
# mapa de calor:
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un mapa de calor para la matriz de correlación de Pearson
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Mapa de Calor de la Correlación de Pearson")
plt.show()

# Crear un mapa de calor para la matriz de correlación de Spearman
plt.figure(figsize=(10, 8))
sns.heatmap(spearman_corr, annot=True, cmap='viridis', center=0)
plt.title("Mapa de Calor de la Correlación de Spearman")
plt.show()

# Crear un mapa de calor para la matriz de correlación de Kendall
plt.figure(figsize=(10, 8))
sns.heatmap(kendall_corr, annot=True, cmap='plasma', center=0)
plt.title("Mapa de Calor de la Correlación de Kendall")
plt.show()

# %% [markdown]
# ### Los mapas de calor te permiten identificar fácilmente:
#
# - Correlaciones fuertes y positivas: Valores cercanos a 1 indican que ambas variables tienden a aumentar juntas.
# - Correlaciones fuertes y negativas: Valores cercanos a -1 indican que una variable tiende a aumentar cuando la otra disminuye.
# - Correlaciones débiles o nulas: Valores cercanos a 0 indican que no hay una relación lineal clara entre las variables.
